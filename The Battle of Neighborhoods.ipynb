# %% [markdown]
# # Youtubers Annual Meeting Organization

# %% [markdown]
# ## Introduction

# %% [markdown]
# Agenda Events is a Toronto's based company focus on organizing events and is currently working on a project to organize the Youtubers Annual Meeting. The event will take place during 7 days in which the most famoust youtubers from all over the world will get together to analice trending topics.
#
# The company has to determine a good program, including a hotel of residence, a hall of meetings, places of landscape to visit, places of shopping, restaurants and coffe shops.
#
# The target of Agenda Events, is to make a list of places of landscape in Toronto, including the nearest restaurants, coffe shops, and shopping stores for each place. And it has to provide a map in case photograhper can't use his/her mobile application for any reason.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data used in this project is provided by Forthsquare location data. The data was grouped by landscape area, and each area include the information about restaurants, coffe shops and stores whithin the area.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 01- Import Libraries.\
# 02- Define Foursquare Credentials.\
# 03- Define the city and get its latitude & longitude.\
# 04- Search for Hotels & clean dataframe.\
# 05- Search for Parks & clean dataframe.\
# 06- Search for Restaurants & clean dataframe.\
# 07- Search for Cafeteria & clean dataframe.\
# 08- Search for Shopping Stores & clean dataframe.\
# 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together.\
# 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together.

# %% [markdown]
# ## Import Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0          conda-forge
#     geopy:         2.0.0-pyh9f0ad1d_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ## Define Foursquare Credentials

# %%
ClIENT_ID = 'XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM' # your Foursquare ID
ClIENT_SECRET = 'AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM
# Foursquare_Secret:AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK

# %% [markdown]
# ## Define the city and get its latitude & longitude

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %% [markdown]
# ## Search for Hotels

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM&client_secret=AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK&ll=43.6534817,-79.3839347&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
#
#                          id        location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3   123 Queen Street West          CA       Toronto
# 1  4ae61cf6f964a520caa421e3         200 Victoria St          CA       Toronto
# 2  51d212c3498ebf27dc469bc9  33 Gerrard Street West          CA       Toronto
# 3  4af96fbbf964a520c01122e3             1 King St W          CA       Toronto
# 4  4b68aed1f964a520de862be3          194 Queen St W          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                324
# 1           Canada         at Shuter St                410
# 2           Canada          at Yonge St                562
# 3           Canada         at Yonge St.                686
# 4           Canada  Queen & St. Patrick                499
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [200 Victoria St (at Shuter St), Toronto ON, C...
# 2  [33 Gerrard Street West (at Yonge St), Toronto...
# 3  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 4  [194 Queen St W (Queen & St. Patrick), Toronto...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...     43.650594
# 1  [{'label': 'display', 'lat': 43.65449797039222...     43.654498
# 2  [{'label': 'display', 'lat': 43.65849759157591...     43.658498
# 3  [{'label': 'display', 'lat': 43.6491395, 'lng'...     43.649139
# 4  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384530                   NaN             M5H 2M9             ON
# 1    -79.379035                   NaN                 NaN             ON
# 2    -79.383097                   NaN             M5G 1Z4             ON
# 3    -79.377876                   NaN             M5H 1A1             ON
# 4    -79.388577                   NaN             M5V 1Z1             ON
#
#                               name    referralId venuePage.id
# 0    Sheraton Centre Toronto Hotel  v-1595794099          NaN
# 1             Pantages Hotel & Spa  v-1595794099          NaN
# 2                    Chelsea Hotel  v-1595794099          NaN
# 3  One King West Hotel & Residence  v-1595794099          NaN
# 4   The Rex Hotel Jazz & Blues Bar  v-1595794099     62225795

# %% [markdown]
# ## Clean Hotel Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                               name categories                 address  cc  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West  CA
# 1             Pantages Hotel & Spa      Hotel         200 Victoria St  CA
# 2                    Chelsea Hotel      Hotel  33 Gerrard Street West  CA
# 3  One King West Hotel & Residence      Hotel             1 King St W  CA
# 4   The Rex Hotel Jazz & Blues Bar  Jazz Club          194 Queen St W  CA
#
#       city country          crossStreet  distance  \
# 0  Toronto  Canada          at York St.       324
# 1  Toronto  Canada         at Shuter St       410
# 2  Toronto  Canada          at Yonge St       562
# 3  Toronto  Canada         at Yonge St.       686
# 4  Toronto  Canada  Queen & St. Patrick       499
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [200 Victoria St (at Shuter St), Toronto ON, C...
# 2  [33 Gerrard Street West (at Yonge St), Toronto...
# 3  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 4  [194 Queen St W (Queen & St. Patrick), Toronto...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...  43.650594 -79.384530
# 1  [{'label': 'display', 'lat': 43.65449797039222...  43.654498 -79.379035
# 2  [{'label': 'display', 'lat': 43.65849759157591...  43.658498 -79.383097
# 3  [{'label': 'display', 'lat': 43.6491395, 'lng'...  43.649139 -79.377876
# 4  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN        NaN    ON  4ae61cf6f964a520caa421e3
# 2          NaN    M5G 1Z4    ON  51d212c3498ebf27dc469bc9
# 3          NaN    M5H 1A1    ON  4af96fbbf964a520c01122e3
# 4          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 1                             Pantages Hotel & Spa
# 2                                    Chelsea Hotel
# 3                  One King West Hotel & Residence
# 4                   The Rex Hotel Jazz & Blues Bar
# 5                    Crew Room Eaton Chelsea Hotel
# 6                                   VFM Test Hotel
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 8                                  Stathcona Hotel
# 9                Sheraton Centre Hotel Club Lounge
# 10                                  Pentagos hotel
# 11  Sheraton Centre Toronto Hotel - Grand Ballroom
# 12                Shizen Spa at the Pantages Hotel
# 13                                       650 Hotel
# 14                               Be SixFifty Hotel
# 15                   Pantages Hotel Toronto Centre
# 16                              Pantages Hotel Gym
# 17                   The Spa At The Adelaide Hotel
# 18                    Bond Place Hotel Parking Lot
# 19         Smoldering remains of the Empress Hotel
# 20  Chelsea Hotel, Toronto Meetings & Events Venue
# 21                      The Adelaide Hotel Toronto
# 22                                  St Regis Hotel
# 23              Henri's Bar at One King West hotel
# 24           Suites at One King West Hotel Toronto
# 25                           89 Chestnut Residence
# 26                            DoubleTree by Hilton
# 27                                          Hilton
# 28    Marriott Downtown at CF Toronto Eaton Centre
# 29                                  Fitness Centre
#
#                                   categories                        address  \
# 0                                      Hotel          123 Queen Street West
# 1                                      Hotel                200 Victoria St
# 2                                      Hotel         33 Gerrard Street West
# 3                                      Hotel                    1 King St W
# 4                                  Jazz Club                 194 Queen St W
# 5                                      Hotel         33 Gerrard Street West
# 6                                      Hotel                 123 Test Drive
# 7                                      Hotel                  8 Colborne St
# 8                                      Hotel                            NaN
# 9                                     Lounge                            NaN
# 10  Residential Building (Apartment / Condo)                            NaN
# 11                                  Ballroom          123 Queen Street West
# 12                                       Spa                200 Victoria St
# 13                                     Hotel                 650 Bay Street
# 14                                     Hotel                 650 Bay Street
# 15  Residential Building (Apartment / Condo)            200 Victoria Street
# 16                                       Gym               200 Victoria St.
# 17                                       Spa                     325 Bay St
# 18                        Miscellaneous Shop                Bond And Dundas
# 19                                     Hotel                   335 Yonge St
# 20                         Convention Center         33 Gerrard Street West
# 21                                     Hotel                     325 Bay St
# 22                                     Hotel                     325 Bay St
# 23                       American Restaurant                    1 King West
# 24                                     Hotel  1 King St W Toronto ON Canada
# 25                    College Residence Hall                89 Chestnut St.
# 26                                     Hotel            108 Chestnut Street
# 27                                     Hotel              145 Richmond St W
# 28                                     Hotel                 525 Bay Street
# 29                                       Gym                    525 Bay St.
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 1   43.654498 -79.379035        NaN    ON
# 2   43.658498 -79.383097    M5G 1Z4    ON
# 3   43.649139 -79.377876    M5H 1A1    ON
# 4   43.650505 -79.388577    M5V 1Z1    ON
# 5   43.658094 -79.382711        NaN    ON
# 6   43.658434 -79.387894    M2M 2M2    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 8   43.654947 -79.386359        NaN    ON
# 9   43.651063 -79.384527    M5H 2M9    ON
# 10  43.653976 -79.379875        NaN    ON
# 11  43.651200 -79.384520        NaN    ON
# 12  43.655198 -79.379913        NaN    ON
# 13  43.657046 -79.384411        NaN    ON
# 14  43.657120 -79.384560        NaN    ON
# 15  43.655205 -79.379182    M5B 1V8    ON
# 16  43.654464 -79.379036    M5B 1V8    ON
# 17  43.649725 -79.380346    M5H 4G5    ON
# 18  43.656224 -79.378830        NaN   NaN
# 19  43.657956 -79.381698        NaN    ON
# 20  43.658446 -79.382985    M5G 1Z4    ON
# 21  43.649831 -79.380164    M5H 4G3    ON
# 22  43.649770 -79.380701    M5H 4G3    ON
# 23  43.648945 -79.378028        NaN    ON
# 24  43.649077 -79.378468        NaN    ON
# 25  43.654160 -79.385291    M5G 1R1    ON
# 26  43.654608 -79.385942    M5G 1R3    ON
# 27  43.649946 -79.385479    M5H 2L2    ON
# 28  43.654728 -79.382422    M5G 2L2    ON
# 29  43.654690 -79.381739    M5G 2L2    ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 2                                    Chelsea Hotel
# 3                  One King West Hotel & Residence
# 4                   The Rex Hotel Jazz & Blues Bar
# 6                                   VFM Test Hotel
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 15                   Pantages Hotel Toronto Centre
# 16                              Pantages Hotel Gym
# 17                   The Spa At The Adelaide Hotel
# 20  Chelsea Hotel, Toronto Meetings & Events Venue
# 21                      The Adelaide Hotel Toronto
# 22                                  St Regis Hotel
# 25                           89 Chestnut Residence
# 26                            DoubleTree by Hilton
# 27                                          Hilton
# 28    Marriott Downtown at CF Toronto Eaton Centre
# 29                                  Fitness Centre
#
#                                   categories                 address  \
# 0                                      Hotel   123 Queen Street West
# 2                                      Hotel  33 Gerrard Street West
# 3                                      Hotel             1 King St W
# 4                                  Jazz Club          194 Queen St W
# 6                                      Hotel          123 Test Drive
# 7                                      Hotel           8 Colborne St
# 15  Residential Building (Apartment / Condo)     200 Victoria Street
# 16                                       Gym        200 Victoria St.
# 17                                       Spa              325 Bay St
# 20                         Convention Center  33 Gerrard Street West
# 21                                     Hotel              325 Bay St
# 22                                     Hotel              325 Bay St
# 25                    College Residence Hall         89 Chestnut St.
# 26                                     Hotel     108 Chestnut Street
# 27                                     Hotel       145 Richmond St W
# 28                                     Hotel          525 Bay Street
# 29                                       Gym             525 Bay St.
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 2   43.658498 -79.383097    M5G 1Z4    ON
# 3   43.649139 -79.377876    M5H 1A1    ON
# 4   43.650505 -79.388577    M5V 1Z1    ON
# 6   43.658434 -79.387894    M2M 2M2    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 15  43.655205 -79.379182    M5B 1V8    ON
# 16  43.654464 -79.379036    M5B 1V8    ON
# 17  43.649725 -79.380346    M5H 4G5    ON
# 20  43.658446 -79.382985    M5G 1Z4    ON
# 21  43.649831 -79.380164    M5H 4G3    ON
# 22  43.649770 -79.380701    M5H 4G3    ON
# 25  43.654160 -79.385291    M5G 1R1    ON
# 26  43.654608 -79.385942    M5G 1R3    ON
# 27  43.649946 -79.385479    M5H 2L2    ON
# 28  43.654728 -79.382422    M5G 2L2    ON
# 29  43.654690 -79.381739    M5G 2L2    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 2                                  Chelsea Hotel      Hotel
# 3                One King West Hotel & Residence      Hotel
# 6                                 VFM Test Hotel      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 21                    The Adelaide Hotel Toronto      Hotel
# 22                                St Regis Hotel      Hotel
# 26                          DoubleTree by Hilton      Hotel
# 27                                        Hilton      Hotel
# 28  Marriott Downtown at CF Toronto Eaton Centre      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 3              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 21              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 22              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 26     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 27       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 28          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 2                                  Chelsea Hotel      Hotel
# 3                One King West Hotel & Residence      Hotel
# 6                                 VFM Test Hotel      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 21                    The Adelaide Hotel Toronto      Hotel
# 22                                St Regis Hotel      Hotel
# 26                          DoubleTree by Hilton      Hotel
# 27                                        Hilton      Hotel
# 28  Marriott Downtown at CF Toronto Eaton Centre      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 3              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 21              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 22              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 26     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 27       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 28          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                             name categories                address        lat  \
# 0  Sheraton Centre Toronto Hotel      Hotel  123 Queen Street West  43.650594
#
#         lng postalCode state
# 0 -79.38453    M5H 2M9    ON

# %% [markdown]
# ## Search for Parks

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM&client_secret=AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK&ll=43.6534817,-79.3839347&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...    False
#
#                          id          location.address location.cc  \
# 0  4b170e47f964a5208cc123e3        691 University Ave          CA
# 1  4b54deadf964a520a3d027e3                       NaN          CA
# 2  4b9d206bf964a520e69136e3           University Ave.          CA
# 3  4bfc5019da7120a132df49fd  450 Adelaide Street West          CA
# 4  4b9177e4f964a520d2be33e3                       NaN          CA
#
#   location.city location.country      location.crossStreet  location.distance  \
# 0       Toronto           Canada             at College St                887
# 1       Toronto           Canada                       NaN                663
# 2       Toronto           Canada         at Wellesley Ave.               1340
# 3       Toronto           Canada  Brant St & Adelaide St W               1372
# 4       Toronto           Canada                       NaN                389
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [University Ave. (at Wellesley Ave.), Toronto ...
# 3  [450 Adelaide Street West (Brant St & Adelaide...
# 4                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.66394609897775...     43.663946
# 3  [{'label': 'display', 'lat': 43.64738759338116...     43.647388
# 4  [{'label': 'display', 'lat': 43.650735, 'lng':...     43.650735
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.392180             M5R 2E8             ON
# 3    -79.398752                 NaN             ON
# 4    -79.386921                 NaN             ON
#
#                                  name    referralId venuePage.id
# 0         Queen's Park Subway Station  v-1595794108          NaN
# 1                         Grange Park  v-1595794108          NaN
# 2                        Queen's Park  v-1595794108          NaN
# 3   St. Andrews Playground / Dog Park  v-1595794108          NaN
# 4  TTC Streetcar #403 - Victoria park  v-1595794108          NaN

# %% [markdown]
# ## Clean Park Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                  name          categories  \
# 0         Queen's Park Subway Station       Metro Station
# 1                         Grange Park                Park
# 2                        Queen's Park                Park
# 3   St. Andrews Playground / Dog Park                Park
# 4  TTC Streetcar #403 - Victoria park  Light Rail Station
#
#                     address  cc     city country               crossStreet  \
# 0        691 University Ave  CA  Toronto  Canada             at College St
# 1                       NaN  CA  Toronto  Canada                       NaN
# 2           University Ave.  CA  Toronto  Canada         at Wellesley Ave.
# 3  450 Adelaide Street West  CA  Toronto  Canada  Brant St & Adelaide St W
# 4                       NaN  CA  Toronto  Canada                       NaN
#
#    distance                                   formattedAddress  \
# 0       887  [691 University Ave (at College St), Toronto O...
# 1       663  [btwn College, University, Queen & Spadina, To...
# 2      1340  [University Ave. (at Wellesley Ave.), Toronto ...
# 3      1372  [450 Adelaide Street West (Brant St & Adelaide...
# 4       389                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.66394609897775...  43.663946 -79.392180
# 3  [{'label': 'display', 'lat': 43.64738759338116...  43.647388 -79.398752
# 4  [{'label': 'display', 'lat': 43.650735, 'lng':...  43.650735 -79.386921
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5R 2E8    ON  4b9d206bf964a520e69136e3
# 3        NaN    ON  4bfc5019da7120a132df49fd
# 4        NaN    ON  4b9177e4f964a520d2be33e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                   name  \
# 0          Queen's Park Subway Station
# 1                          Grange Park
# 2                         Queen's Park
# 3    St. Andrews Playground / Dog Park
# 4   TTC Streetcar #403 - Victoria park
# 5                  Riverdale Park West
# 6                        One Park Lane
# 7               Trinity Bellwoods Park
# 8               Physiomed College Park
# 9                 Bellevue Square Park
# 10                 Riverdale Park East
# 11                         Berczy Park
# 12       Crunch Fitness - College Park
# 13                            HTO Park
# 14                Clarence Square Park
# 15    Residences at College Park North
# 16    Toothworks - College Park Dental
# 17             Moss Park Tennis Courts
# 18                  Canoe Landing Park
# 19                     Coronation Park
# 20              Parliament Square Park
# 21        Orphan's Greenspace Dog Park
# 22                   Barbara Hall Park
# 23                   Barbara Hall Park
# 24             St Lawrence on the Park
# 25                 Tommy Thompson Park
# 26                         Regent Park
# 27                           High Park
# 28           Village of Yorkville Park
# 29                        Stanley Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park               University Ave.
# 3                                       Park      450 Adelaide Street West
# 4                         Light Rail Station                           NaN
# 5                                       Park               500 Gerrard St.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                                       Park            1053 Dundas St. W.
# 8                             Medical Center                  382 Yonge St
# 9                                       Park  btwn Bellevue & Augusta Ave.
# 10                                      Park             550 Broadview Ave
# 11                                      Park        35 Wellington St. East
# 12                      Gym / Fitness Center              382 Yonge Street
# 13                                      Park                  Queen's Quay
# 14                                      Park                   Spadina Ave
# 15  Residential Building (Apartment / Condo)                   763 Bay St.
# 16                          Dentist's Office        444 Yonge St, Unit M16
# 17                              Tennis Court                     Moss Park
# 18                                      Park             50 Fort York Blvd
# 19                                      Park        711 Lake Shore Blvd. W
# 20                                      Park          44 Parliament Street
# 21                                   Dog Run                  51 Power St.
# 22                                      Park                 519 Church St
# 23                                      Park             519 Church Street
# 24                                  Building               65 Scadding Ave
# 25                                      Park                     Leslie St
# 26                              Neighborhood                           NaN
# 27                                      Park              1873 Bloor St. W
# 28                                      Park            115 Cumberland St.
# 29                                      Park              King Street West
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.663946 -79.392180    M5R 2E8    ON
# 3   43.647388 -79.398752        NaN    ON
# 4   43.650735 -79.386921        NaN    ON
# 5   43.666048 -79.360941    M5A 2H3    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 8   43.659240 -79.382860    M5B 1S8    ON
# 9   43.653610 -79.402199    M5T 2N4    ON
# 10  43.669951 -79.355493    M4K 2P1    ON
# 11  43.648048 -79.375172        NaN    ON
# 12  43.659263 -79.382632    M5G 1S8    ON
# 13  43.637949 -79.387820        NaN    ON
# 14  43.644222 -79.394230        NaN    ON
# 15  43.659822 -79.385159    M5G 2R3    ON
# 16  43.660009 -79.383905        NaN    ON
# 17  43.655337 -79.371923        NaN    ON
# 18  43.638762 -79.397067    M5V 3Z1    ON
# 19  43.634553 -79.405403    M5V 3T7    ON
# 20  43.650264 -79.362195        NaN    ON
# 21  43.654654 -79.362501        NaN    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 23  43.666728 -79.381084        NaN    ON
# 24  43.648963 -79.364868        NaN    ON
# 25  43.634180 -79.323671        NaN    ON
# 26  43.660009 -79.364191        NaN    ON
# 27  43.646479 -79.463425    M6R 2Z3    ON
# 28  43.670186 -79.391180        NaN    ON
# 29  43.642395 -79.409330        NaN    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 2                       Queen's Park
# 5                Riverdale Park West
# 6                      One Park Lane
# 7             Trinity Bellwoods Park
# 8             Physiomed College Park
# 9               Bellevue Square Park
# 10               Riverdale Park East
# 12     Crunch Fitness - College Park
# 15  Residences at College Park North
# 18                Canoe Landing Park
# 19                   Coronation Park
# 22                 Barbara Hall Park
# 27                         High Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                                       Park               University Ave.
# 5                                       Park               500 Gerrard St.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                                       Park            1053 Dundas St. W.
# 8                             Medical Center                  382 Yonge St
# 9                                       Park  btwn Bellevue & Augusta Ave.
# 10                                      Park             550 Broadview Ave
# 12                      Gym / Fitness Center              382 Yonge Street
# 15  Residential Building (Apartment / Condo)                   763 Bay St.
# 18                                      Park             50 Fort York Blvd
# 19                                      Park        711 Lake Shore Blvd. W
# 22                                      Park                 519 Church St
# 27                                      Park              1873 Bloor St. W
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.663946 -79.392180    M5R 2E8    ON
# 5   43.666048 -79.360941    M5A 2H3    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 8   43.659240 -79.382860    M5B 1S8    ON
# 9   43.653610 -79.402199    M5T 2N4    ON
# 10  43.669951 -79.355493    M4K 2P1    ON
# 12  43.659263 -79.382632    M5G 1S8    ON
# 15  43.659822 -79.385159    M5G 2R3    ON
# 18  43.638762 -79.397067    M5V 3Z1    ON
# 19  43.634553 -79.405403    M5V 3T7    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 27  43.646479 -79.463425    M6R 2Z3    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2             Queen's Park       Park               University Ave.
# 5      Riverdale Park West       Park               500 Gerrard St.
# 7   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 9     Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 10     Riverdale Park East       Park             550 Broadview Ave
# 18      Canoe Landing Park       Park             50 Fort York Blvd
# 19         Coronation Park       Park        711 Lake Shore Blvd. W
# 22       Barbara Hall Park       Park                 519 Church St
# 27               High Park       Park              1873 Bloor St. W
#
#           lat        lng postalCode state
# 2   43.663946 -79.392180    M5R 2E8    ON
# 5   43.666048 -79.360941    M5A 2H3    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 9   43.653610 -79.402199    M5T 2N4    ON
# 10  43.669951 -79.355493    M4K 2P1    ON
# 18  43.638762 -79.397067    M5V 3Z1    ON
# 19  43.634553 -79.405403    M5V 3T7    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 27  43.646479 -79.463425    M6R 2Z3    ON

# %% [markdown]
# ## Search for Restaurants

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM&client_secret=AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK&ll=43.6534817,-79.3839347&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 4  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ada5d5bf964a520e92121e3         35 Church St          CA       Toronto
# 1  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 2  4ad4c05cf964a52006f620e3  37 King Street East          CA       Toronto
# 3  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 4  5750b013498e755287c6de97   988 Baldwin Street          CA       Toronto
#
#   location.country              location.crossStreet  location.distance  \
# 0           Canada                     at Front St E                973
# 1           Canada                               NaN                224
# 2           Canada  at Le Meridien King Edward Hotel                763
# 3           Canada                     at D'Arcy St.               1188
# 4           Canada                               NaN                839
#
#                            location.formattedAddress  \
# 0  [35 Church St (at Front St E), Toronto ON M5E ...
# 1  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2  [37 King Street East (at Le Meridien King Edwa...
# 3  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4           [988 Baldwin Street, Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.64882370529773...     43.648824
# 1  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 2  [{'label': 'display', 'lat': 43.64929834396347...     43.649298
# 3  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 4  [{'label': 'display', 'lat': 43.655874, 'lng':...     43.655874
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.373702                   NaN             M5E 1T3             ON
# 1    -79.385931                   NaN             M5G 1R3             ON
# 2    -79.376431                   NaN             M5C 1E9             ON
# 3    -79.398650     Kensington Market             M5T 2E9             ON
# 4    -79.393826                   NaN                 NaN             ON
#
#                                  name    referralId venuePage.id
# 0      The Hot House Restaurant & Bar  v-1595794112          NaN
# 1     Hemispheres Restaurant & Bistro  v-1595794112          NaN
# 2               Victoria's Restaurant  v-1595794112    498556908
# 3              Rol San Restaurant 龍笙棧  v-1595794112          NaN
# 4  Some Time BBQ Grill Restaurant 碳烤屋  v-1595794112          NaN

# %% [markdown]
# ## Clean Restaurant Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0      The Hot House Restaurant & Bar  American Restaurant
# 1     Hemispheres Restaurant & Bistro  American Restaurant
# 2               Victoria's Restaurant           Restaurant
# 3              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 4  Some Time BBQ Grill Restaurant 碳烤屋  Szechuan Restaurant
#
#                address  cc     city country                       crossStreet  \
# 0         35 Church St  CA  Toronto  Canada                     at Front St E
# 1  110 Chestnut Street  CA  Toronto  Canada                               NaN
# 2  37 King Street East  CA  Toronto  Canada  at Le Meridien King Edward Hotel
# 3     323 Spadina Ave.  CA  Toronto  Canada                     at D'Arcy St.
# 4   988 Baldwin Street  CA  Toronto  Canada                               NaN
#
#    distance                                   formattedAddress  \
# 0       973  [35 Church St (at Front St E), Toronto ON M5E ...
# 1       224  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2       763  [37 King Street East (at Le Meridien King Edwa...
# 3      1188  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4       839           [988 Baldwin Street, Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.64882370529773...  43.648824 -79.373702
# 1  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 2  [{'label': 'display', 'lat': 43.64929834396347...  43.649298 -79.376431
# 3  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 4  [{'label': 'display', 'lat': 43.655874, 'lng':...  43.655874 -79.393826
#
#         neighborhood postalCode state                        id
# 0                NaN    M5E 1T3    ON  4ada5d5bf964a520e92121e3
# 1                NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 2                NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 3  Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 4                NaN        NaN    ON  5750b013498e755287c6de97

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                   The Hot House Restaurant & Bar      American Restaurant
# 1                  Hemispheres Restaurant & Bistro      American Restaurant
# 2                            Victoria's Restaurant               Restaurant
# 3                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 4               Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 5                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                     Aroma Fine Indian Restaurant        Indian Restaurant
# 7          Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 8                                Studio Restaurant           Breakfast Spot
# 9                           Azure Restaurant & Bar               Restaurant
# 10              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 11              Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 12                   Green Tea Restaurant Downtown       Chinese Restaurant
# 13               Kensington Cornerstone Restaurant           Breakfast Spot
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                     Cottage Restaurant & Lounge          Thai Restaurant
# 16                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 17                         Victor Restaurant & Bar                      Bar
# 18                                  360 Restaurant                 Wine Bar
# 19                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 20  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 21                           Sightlines Restaurant      American Restaurant
# 22                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 23                           Restaurant | Adelaide               Restaurant
# 24                           ONE Restaurant/Lounge  New American Restaurant
# 25                   Micheal's Restaurant and Deli                      Bar
# 26             Richtree Natural Market Restaurants               Restaurant
# 27                         New Treasure Restaurant       Dim Sum Restaurant
# 28                         Osgoode Hall Restaurant  New American Restaurant
# 29                    Yueh Tung Chinese Restaurant       Chinese Restaurant
#
#                             address        lat        lng postalCode state
# 0                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 1               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 5                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 7                   405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 8                    389 Church St.  43.661500 -79.379319        M5B    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 11                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 12  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 13               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 16                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 17                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 18                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 19                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 21                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 22              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 23          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 24                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 25                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 26                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 27                  150 Dundas St W  43.655384 -79.385362        NaN    ON
# 28                   130 Queen St W  43.651979 -79.385049    M5H 2N6   NaN
# 29                126 Elizabeth St.  43.655281 -79.385337    M5G 1P5    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name            categories  \
# 0                   The Hot House Restaurant & Bar   American Restaurant
# 1                  Hemispheres Restaurant & Bistro   American Restaurant
# 2                            Victoria's Restaurant            Restaurant
# 3                           Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 5                   Goldstone Noodle Restaurant 金石          Noodle House
# 6                     Aroma Fine Indian Restaurant     Indian Restaurant
# 7          Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 8                                Studio Restaurant        Breakfast Spot
# 9                           Azure Restaurant & Bar            Restaurant
# 12                   Green Tea Restaurant Downtown    Chinese Restaurant
# 13               Kensington Cornerstone Restaurant        Breakfast Spot
# 14                        Ka Chi Korean Restaurant     Korean Restaurant
# 15                     Cottage Restaurant & Lounge       Thai Restaurant
# 16                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 17                         Victor Restaurant & Bar                   Bar
# 18                                  360 Restaurant              Wine Bar
# 19                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 20  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 23                           Restaurant | Adelaide            Restaurant
# 26             Richtree Natural Market Restaurants            Restaurant
# 29                    Yueh Tung Chinese Restaurant    Chinese Restaurant
#
#                             address        lat        lng postalCode state
# 0                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 1               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 5                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 7                   405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 8                    389 Church St.  43.661500 -79.379319        M5B    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 12  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 13               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 16                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 17                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 18                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 19                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 23          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 26                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29                126 Elizabeth St.  43.655281 -79.385337    M5G 1P5    ON

# %% [markdown]
# ## Search for Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM&client_secret=AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK&ll=43.6534817,-79.3839347&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  4b57256bf964a520332828e3                                      Yonge
# 3  53bd6dfe498e6c1d3bc9333e                                        NaN
# 4  524f1c8f498e983dde61ada0                         89 Chestnut Street
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada               Dundas
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                448  [The Hospital for Sick Children (SickKids), To...
# 1               1246  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                387               [Yonge (Dundas), Toronto ON, Canada]
# 3                505                               [Toronto ON, Canada]
# 4                584           [89 Chestnut Street, Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65603785909391...     43.656038
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...     43.648231
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.380672                 NaN             ON
# 3    -79.389443                 NaN             ON
# 4    -79.384045                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1595794114
# 1              Stay Cafeteria 慢走  v-1595794114
# 2                Sears Cafeteria  v-1595794114
# 3  Industrial Alliance Cafeteria  v-1595794114
# 4        Chestnut Tree Cafeteria  v-1595794114

# %% [markdown]
# ## Clean Cafeteria Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                Sears Cafeteria            Food Court
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4        Chestnut Tree Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                                      Yonge  CA  Toronto  Canada
# 3                                        NaN  CA  Toronto  Canada
# 4                         89 Chestnut Street  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       448  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St      1246  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2        Dundas       387               [Yonge (Dundas), Toronto ON, Canada]
# 3           NaN       505                               [Toronto ON, Canada]
# 4           NaN       584           [89 Chestnut Street, Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65603785909391...  43.656038 -79.380672
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...  43.648231 -79.384045
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  4b57256bf964a520332828e3
# 3        NaN    ON  53bd6dfe498e6c1d3bc9333e
# 4        NaN    ON  524f1c8f498e983dde61ada0

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                         Sears Cafeteria            Food Court
# 3           Industrial Alliance Cafeteria             Cafeteria
# 4                 Chestnut Tree Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                          OCAD Cafeteria     College Cafeteria
# 7                   Ryerson Hub Cafeteria     College Cafeteria
# 8                      SickKids Cafeteria            Food Court
# 9           De La Salle College Cafeteria     College Cafeteria
# 10                      Med Sci Cafeteria     College Cafeteria
# 11              Macdonald Block Cafeteria             Cafeteria
# 12                      Robarts Cafeteria     College Cafeteria
# 13                          OMP Cafeteria             Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                      Choices Cafeteria            Food Court
# 16    Cafeteria, Lawrence Park Collegiate           High School
# 17    Cafeteria, Lawrence Park Collegiate           Event Space
# 18                             Marketeria            Restaurant
# 19                       Kasala Cafeteria    African Restaurant
# 20                                The Hub     College Cafeteria
# 21               Estonian House Cafeteria                  Café
# 22                           CC Cafeteria     College Cafeteria
# 23                             Radio Cafe            Food Court
# 24     Lawrence Park Collegiate Cafeteria           High School
# 25                           L5 Cafeteria      Cuban Restaurant
# 26  6th Floor Cafeteria 12 Concorde Place                  Café
# 27                          Innis College        Student Center
# 28  George Brown College St. James Campus     Community College
# 29                      Glendon Cafeteria     College Cafeteria
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                                       Yonge  43.656038 -79.380672
# 3                                         NaN  43.655657 -79.389443
# 4                          89 Chestnut Street  43.648231 -79.384045
# 5                                         NaN  43.654179 -79.392555
# 6                              100 McCaul St.  43.652780 -79.391762
# 7                            350 Victoria St.  43.658475 -79.377653
# 8                       555 University Avenue  43.657584 -79.375652
# 9                          131 Farnham Avenue  43.683003 -79.397815
# 10                                        NaN  43.660260 -79.392977
# 11                                        NaN  43.663212 -79.388062
# 12                         130 St. George St.  43.664864 -79.399766
# 13                           1 Mount Pleasant  43.669801 -79.379790
# 14                                        NaN  43.669904 -79.379748
# 15                         200 Bloor Street E  43.671411 -79.381849
# 16                                        NaN  43.721732 -79.409600
# 17                                        NaN  43.723286 -79.412222
# 18                                30 Bond St.  43.653585 -79.378843
# 19                                      Bloor  43.660759 -79.424018
# 20                           350 Victoria St.  43.658585 -79.380622
# 21                       958 Broadview avenue  43.681763 -79.358246
# 22                             951 Carlaw Ave  43.684631 -79.348862
# 23                          333 Bloor st east  43.671696 -79.380617
# 24                                        NaN  43.722757 -79.413734
# 25                                        NaN  43.723019 -79.345012
# 26                          12 Concorde Place  43.721861 -79.329339
# 27                               2 Sussex Ave  43.665556 -79.399298
# 28                          200 King St. East  43.651366 -79.370158
# 29                           2275 Bayview Ave  43.727383 -79.378080
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3         NaN    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8         NaN    ON
# 9     M4V 1H7    ON
# 10        NaN    ON
# 11        NaN   NaN
# 12        NaN    ON
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN   NaN
# 17        NaN   NaN
# 18    M5B 1W8    ON
# 19        NaN   NaN
# 20    M5B 2K3    ON
# 21        NaN    ON
# 22        NaN    ON
# 23        NaN    ON
# 24        NaN    ON
# 25        NaN   NaN
# 26    m3c 3k7    ON
# 27    M5S 1J5    ON
# 28        NaN    ON
# 29        NaN    ON

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 9           De La Salle College Cafeteria  College Cafeteria
# 18                             Marketeria         Restaurant
# 20                                The Hub  College Cafeteria
# 26  6th Floor Cafeteria 12 Concorde Place               Café
# 27                          Innis College     Student Center
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 9   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 18         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 20    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 26   12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 27        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON

# %% [markdown]
# ## Search for Shopping Stores

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XMPFCEA0M223YP3BJQZC1X145XBIDH0VTCM32YBR0BAKC3PM&client_secret=AAHPZ55Z1LXWJZKD0VJLDW51OCZ3MXQO5VFD1IDI5MZKF1ZK&ll=43.6534817,-79.3839347&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
#
#                          id    location.address location.cc location.city  \
# 0  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada    Queen Street West                424
# 1           Canada  btwn Queen & Dundas                287
# 2           Canada    btw York & Bay St                741
#
#                            location.formattedAddress  \
# 0  [176 Yonge Street (Queen Street West), Toronto...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 1                                                NaN     43.654540
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.379192                            NaN             M5C 2L7
# 1    -79.380677  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
#
#   location.state                                        name    referralId
# 0             ON  Saks Fifth Avenue Club - Personal Shopping  v-1595794115
# 1             ON                     CF Toronto Eaton Centre  v-1595794115
# 2             ON                TD Centre Shopping Concourse  v-1595794115

# %% [markdown]
# ## Clean Shopping Dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
#
#               address  cc     city country          crossStreet  distance  \
# 0    176 Yonge Street  CA  Toronto  Canada    Queen Street West       424
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       287
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       741
#
#                                     formattedAddress  \
# 0  [176 Yonge Street (Queen Street West), Toronto...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 1                                                NaN  43.654540 -79.380677
# 2  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
#
#               address        lat        lng postalCode state
# 0    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 1        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 1 -79.380677    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ## Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                     name         categories  \
# 0          Sheraton Centre Toronto Hotel              Hotel
# 1                      Stay Cafeteria 慢走   Asian Restaurant
# 2          De La Salle College Cafeteria  College Cafeteria
# 3                             Marketeria         Restaurant
# 4                                The Hub  College Cafeteria
# 5  6th Floor Cafeteria 12 Concorde Place               Café
# 6                          Innis College     Student Center
# 7                CF Toronto Eaton Centre      Shopping Mall
# 8           TD Centre Shopping Concourse      Shopping Mall
#
#                  address        lat        lng postalCode state
# 0  123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1        388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2     131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 3            30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 4       350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 5      12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 6           2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 7           220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 8     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name            categories  \
# 0                                     Queen's Park                  Park
# 1                              Riverdale Park West                  Park
# 2                           Trinity Bellwoods Park                  Park
# 3                             Bellevue Square Park                  Park
# 4                              Riverdale Park East                  Park
# 5                               Canoe Landing Park                  Park
# 6                                  Coronation Park                  Park
# 7                                Barbara Hall Park                  Park
# 8                                        High Park                  Park
# 9                   The Hot House Restaurant & Bar   American Restaurant
# 10                 Hemispheres Restaurant & Bistro   American Restaurant
# 11                           Victoria's Restaurant            Restaurant
# 12                          Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 13                  Goldstone Noodle Restaurant 金石          Noodle House
# 14                    Aroma Fine Indian Restaurant     Indian Restaurant
# 15         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 16                               Studio Restaurant        Breakfast Spot
# 17                          Azure Restaurant & Bar            Restaurant
# 18                   Green Tea Restaurant Downtown    Chinese Restaurant
# 19               Kensington Cornerstone Restaurant        Breakfast Spot
# 20                        Ka Chi Korean Restaurant     Korean Restaurant
# 21                     Cottage Restaurant & Lounge       Thai Restaurant
# 22                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 23                         Victor Restaurant & Bar                   Bar
# 24                                  360 Restaurant              Wine Bar
# 25                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 26  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 27                           Restaurant | Adelaide            Restaurant
# 28             Richtree Natural Market Restaurants            Restaurant
# 29                    Yueh Tung Chinese Restaurant    Chinese Restaurant
# 30                               Stay Cafeteria 慢走      Asian Restaurant
# 31                   De La Salle College Cafeteria     College Cafeteria
# 32                                      Marketeria            Restaurant
# 33                                         The Hub     College Cafeteria
# 34           6th Floor Cafeteria 12 Concorde Place                  Café
# 35                                   Innis College        Student Center
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 2                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 3      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 4                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 5                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 6            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 7                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 8                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 9                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10              110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 11              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 12                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 13                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 14                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 15                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 16                   389 Church St.  43.661500 -79.379319        M5B    ON
# 17                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 18  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 19               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 20                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 21                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 22                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 23                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 24                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 25                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 26            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 27          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 28                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29                126 Elizabeth St.  43.655281 -79.385337    M5G 1P5    ON
# 30                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 31               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 32                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 33                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 34                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 35                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Notebook on Watson

# %% [markdown]
# ### Note: I share the above link with you to see maps
